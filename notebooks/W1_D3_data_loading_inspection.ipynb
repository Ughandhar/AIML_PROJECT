# %%
# W1D3: Data Loading, Cleaning & Inspection

## Objective
Load, inspect, clean, and validate a real dataset using Python and Pandas.

# %%
import pandas as pd
import numpy as np

print("Pandas version:", pd.__version__)
print("NumPy version:", np.__version__)
# Out:
# Pandas version: 3.0.5
# NumPy version: 2.5.2

# %%
df = pd.read_csv("../data/indian_cities.csv")

print("Dataset loaded successfully.")
display(df.head(10))
# Out:
# Dataset loaded successfully.
#         city        state  population_millions  literacy_rate  \
# 0  Bengaluru    Karnataka                 13.6           88.7
# 1     Mumbai  Maharashtra                 21.7           89.7
# 2      Delhi        Delhi                 33.8           86.2
# 3    Chennai   Tamil Nadu                 12.0           90.2
# 4  Hyderabad    Telangana                 10.8           83.3
# 5       Pune  Maharashtra                  7.4           89.4
# 6    Kolkata  West Bengal                 15.0           87.1
# 7  Ahmedabad      Gujarat                  8.9           89.6
# 8     Jaipur    Rajasthan                  4.1           76.4
# 9      Kochi       Kerala                  2.1           96.2
#
#    average_temperature
# 0                 24.0
# 1                 27.2
# 2                 25.0
# 3                 29.0
# 4                 27.0
# 5                 24.5
# 6                 26.5
# 7                 28.5
# 8                 25.8
# ...

# %%
print("Shape:", df.shape)

print("\nColumns:")
print(df.columns.tolist())

print("\nData types:")
print(df.dtypes)
# Out:
# Shape: (10, 5)
#
# Columns:
# ['city', 'state', 'population_millions', 'literacy_rate', 'average_temperature']
#
# Data types:
# city                       str
# state                      str
# population_millions    float64
# literacy_rate          float64
# average_temperature    float64
# dtype: object

# %%
print("Missing values:")
print(df.isnull().sum())

print("\nDuplicate rows:")
print(df.duplicated().sum())
# Out:
# Missing values:
# city                   0
# state                  0
# population_millions    0
# literacy_rate          0
# average_temperature    0
# dtype: int64
#
# Duplicate rows:
# 0

# %%
print("Data quality check:")

assert df.isnull().sum().sum() == 0
assert df.duplicated().sum() == 0

print("✓ No missing values")
print("✓ No duplicate rows")
print("✓ Dataset is ready for use")
# Out:
# Data quality check:
# ✓ No missing values
# ✓ No duplicate rows
# ✓ Dataset is ready for use

# %%
from pathlib import Path

output_dir = Path("../data/output")
output_dir.mkdir(parents=True, exist_ok=True)

output_path = output_dir / "indian_cities_w1d3.csv"

df.to_csv(output_path, index=False)

print("Saved successfully:", output_path)
# Out:
# Saved successfully: ..\data\output\indian_cities_w1d3.csv

# %%
# W1D3 Self-Review

## Data Loading, Cleaning & Inspection

✓ Pandas and NumPy imported  
✓ Indian cities dataset loaded successfully  
✓ Dataset shape and columns inspected  
✓ Data types verified  
✓ Missing values checked  
✓ Duplicate rows checked  
✓ Data quality validated  
✓ Validated dataset exported to CSV  
✓ Notebook outputs verified  

## W1D3 Status COMPLETE
